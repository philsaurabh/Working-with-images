# %% [markdown]
# <a href="https://colab.research.google.com/github/philsaurabh/Working-with-images/blob/main/Keyframe_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extract Keyframes from the videos in a folder.
# (Manual Cleaning will be needed after this extraction. Because of automated work, some frames may be of no use and may belong to another class.)
#
# Extract the Keyframes Folderwise.

# %%
# -*- coding: utf-8 -*-
"""Katna Extract.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1XiGRpHmID5OrD-4B9oLnf1Et237DkMO9
"""

# !pip install katna

from Katna.video import Video
import time
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from Katna.video import Video
from Katna.writer import KeyFrameDiskWriter
import os
import glob

if __name__ == "__main__":
  vd = Video()
  diskwriter = KeyFrameDiskWriter(location="/content/drive/MyDrive/test/val")
  files =glob.glob('/content/drive/MyDrive/test/validation/*.*')
  for file in files:
    vd.extract_video_keyframes(
      no_of_frames=5, file_path=file,
      writer=diskwriter
      )
